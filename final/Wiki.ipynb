# %%
from bs4 import BeautifulSoup
import urllib.request as ulb
import re

# %%
class WikiReptile(object):

    def __init__(self, base_key, deep, relation_path, context_path):
        self.__urlsList = set()
        self.__baseUrl = 'https://en.wikipedia.org'
        self.__baseKey = base_key
        self.__deep = deep
        self.__contextPath = context_path
        self.__relationPath = relation_path

    def __add_url(self, url):
        self.__urlsList.add(url)

    def get_urls_len(self):
        return len(self.__urlsList)

    # 局部广度优先遍历
    def save_list(self, key_url, start_urls, deep_count=0):
        deep_count += 1
        if self.__deep < deep_count:
            return
        print('初始网页 %s 包含链接数 %s' % (key_url[6:], str(len(start_urls))))
        count = 0
        listMap = {}
        for url in start_urls:
            count += 1
            string = key_url[6:] + "\t->\t" + url[6:]
            print('\t%s 保存关系 %s' % (str(count), string))
            self.__apend_relation(self.__relationPath, string)
            if url not in self.__urlsList:
                print('\t\t保存网页 %s' % url[6:])
                success = self.__apend_html("https://en.wikipedia.org%s" % url, self.__contextPath)
                if not success:
                    continue
                self.__urlsList.add(url)
                url_List = self.__get_urls("https://en.wikipedia.org%s" % url)
                if isinstance(url_List, list) and url_List != []:
                    listMap[url] = url_List
        for key, value in listMap.items():
            self.save_list(key, value, deep_count)

    def __open_url(self, url):
        try:
            the_link = ulb.urlopen(url, timeout=10)
            the_read = the_link.read()
        except BaseException:
            print('当前连接失败...放弃并继续')
            return None
        else:
            return the_read

    def __apend_relation(self, path, string):
        try:
            list_file = open(path, "a+", encoding='utf-8')
        except BaseException:
            print('%s打开失败...放弃并继续' % path)
        else:
            try:
                list_file.write(string + "\n")
            except BaseException:
                print('关系写入失败...放弃并继续')
            finally:
                list_file.close()

    def __apend_html(self, the_url, the_path):
        the_read = self.__open_url(the_url)
        if the_read is None:
            return False
        the_html = BeautifulSoup(str(the_read, encoding="utf-8"), "lxml")
        title = self.__get_title(the_html)
        try:
            file = open(the_path, "a+", encoding='utf-8')
        except BaseException:
            print('%s打开失败...放弃并继续' % the_path)
            return False
        else:
            try:
                file.write('1 ' + title + "\n")
                content = self.__get_content(the_html)
                for ele in content:
                    file.write(ele + "\n")
                    if '2 References' in ele:
                        references = self.__get_references(the_html)
                        if references is not None:
                            for reference in references:
                                file.write(reference + "\n")
                file.write("\n" + "=" * 20 + "\n\n")
            except BaseException:
                print('正文写入失败...放弃并继续')
                return False
            finally:
                file.close()
        return True

    def __get_title(self, the_html):
        title = the_html.find("h1", {"id": "firstHeading"}).get_text()
        return title.replace('/', '_')

    def __get_content(self, the_html):
        content = the_html.find("div", {"id": "bodyContent"})
        contents = []
        for ele in content.findAll({"h1", "h2", "h3", "h4", "h5", "h6", "p"}):
            # file.write(str(ele)[2] + " " + ele.get_text() + "\n")
            contents.append(str(ele)[2] + " " + ele.get_text())
        return contents

    def __get_references(self, the_html):
        try:
            content = the_html.find("ol", {"class": "references"})
            refers = content.findAll("li")
        except AttributeError:
            return None
        # print(content.get_text())
        referecces = []
        count = 0
        for ele in refers:
            count += 1
            referecces.append("[" + str(count) + "] " + ele.get_text())
            # print(str(count) + "\t" + ele.get_text())
        return referecces

    def __get_urls(self, init_url):
        the_read = self.__open_url(init_url)
        if the_read is None:
            return
        html = BeautifulSoup(str(the_read, encoding="utf-8"), "lxml")
        content = html.find("div", {"id": "bodyContent"})
        urls = []
        for link in content.findAll("a", href=re.compile("^(/wiki/)((?!:).)*$")):
            if 'href' in link.attrs:
                if link.attrs['href'] not in self.__urlsList:
                    urls.append(link.attrs['href'])
        return urls

    def run(self):
        self.__add_url(self.__baseKey)
        self.__apend_html(self.__baseUrl + self.__baseKey, self.__contextPath)
        urlList = self.__get_urls(self.__baseUrl + self.__baseKey)
        if isinstance(urlList, list) and urlList != []:
            self.save_list(self.__baseKey, urlList)

# %%
# 爬取英文维基百科网页内容
baseKey = '/wiki/Finance'
webDeep = 1
saveUrl = "C:/Users/yuqia/python-project-chatbot-codes/WikiReptile-master/"
relationFileName = "/url_link_list.txt"
contextFileName = "/wiki.txt"
##
# 传入参数
#   base_key         初始网页（不包含维基基础地址）
#   webDeep          爬取深度
#   deep             爬取深度（一个网页到下一个网页为一个深度）
#   relation_path    关系保存文件地址
#   context_path     正文保存文件地址
wiki_reptile = WikiReptile(baseKey, webDeep, saveUrl + relationFileName, saveUrl + contextFileName)
wiki_reptile.run()
print("\t所有网页数： " + str(wiki_reptile.get_urls_len()))
# Out:
# 初始网页 Finance 包含链接数 295
# 	1 保存关系 Finance	->	Finance_(game)
# 		保存网页 Finance_(game)
# 	2 保存关系 Finance	->	The_Financial
# 		保存网页 The_Financial
# 	3 保存关系 Finance	->	Financial_market
# 		保存网页 Financial_market
# 	4 保存关系 Finance	->	Financial_asset
# 		保存网页 Financial_asset
# 	5 保存关系 Finance	->	Bond_market
# 		保存网页 Bond_market
# 	6 保存关系 Finance	->	Commodity_market
# 		保存网页 Commodity_market
# 	7 保存关系 Finance	->	Derivatives_market
# 		保存网页 Derivatives_market
# 	8 保存关系 Finance	->	Foreign_exchange_market
# 		保存网页 Foreign_exchange_market
# 	9 保存关系 Finance	->	Money_market
# 		保存网页 Money_market
# 	10 保存关系 Finance	->	Over-the-counter_(finance)
# 		保存网页 Over-the-counter_(finance)
# 	11 保存关系 Finance	->	Private_equity
# 		保存网页 Private_equity
# 	12 保存关系 Finance	->	Real_estate
# 		保存网页 Real_estate
# 	13 保存关系 Finance	->	Spot_market
# 		保存网页 Spot_market
# 	14 保存关系 Finance	->	Stock_market
# 		保存网页 Stock_market
# 	15 保存关系 Finance	->	Financial_market_participants
# 		保存网页 Financial_market_participants
# 	16 保存关系 Finance	->	Investor
# 		保存网页 Investor
# 	17 保存关系 Finance	->	Institutional_investor
# 		保存网页 Institutional_investor
# 	18 保存关系 Finance	->	Retail
# 		保存网页 Retail
# 	19 保存关系 Finance	->	Speculation
# 		保存网页 Speculation
# 	20 保存关系 Finance	->	Financial_centre
# 		保存网页 Financial_centre
# 	21 保存关系 Finance	->	Financial_centre
# 	22 保存关系 Finance	->	Offshore_financial_centre
# 		保存网页 Offshore_financial_centre
# 	23 保存关系 Finance	->	Conduit_and_Sink_OFCs
# 		保存网页 Conduit_and_Sink_OFCs
# 	24 保存关系 Finance	->	Financial_instrument
# 		保存网页 Financial_instrument
# 	25 保存关系 Finance	->	Bond_(finance)
# 		保存网页 Bond_(finance)
# 	26 保存关系 Finance	->	Cash
# 		保存网页 Cash
# 	27 保存关系 Finance	->	Collateralised_debt_obligation
# 		保存网页 Collateralised_debt_obligation
# 	28 保存关系 Finance	->	Credit_default_swap
# 		保存网页 Credit_default_swap
# 	29 保存关系 Finance	->	Time_deposit
# 		保存网页 Time_deposit
# 	30 保存关系 Finance	->	Certificate_of_deposit
# 		保存网页 Certificate_of_deposit
# 	31 保存关系 Finance	->	Line_of_credit
# 		保存网页 Line_of_credit
# 	32 保存关系 Finance	->	Deposit_account
# 		保存网页 Deposit_account
# 	33 保存关系 Finance	->	Derivative_(finance)
# 		保存网页 Derivative_(finance)
# 	34 保存关系 Finance	->	Futures_contract
# 		保存网页 Futures_contract
# 	35 保存关系 Finance	->	Indemnity
# 		保存网页 Indemnity
# 	36 保存关系 Finance	->	Insurance
# 		保存网页 Insurance
# 	37 保存关系 Finance	->	Letter_of_credit
# 		保存网页 Letter_of_credit
# 	38 保存关系 Finance	->	Loan
# 		保存网页 Loan
# 	39 保存关系 Finance	->	Mortgage
# 		保存网页 Mortgage
# 	40 保存关系 Finance	->	Option_(finance)
# 		保存网页 Option_(finance)
# 	41 保存关系 Finance	->	Call_option
# 		保存网页 Call_option
# 	42 保存关系 Finance	->	Exotic_option
# 		保存网页 Exotic_option
# 	43 保存关系 Finance	->	Put_option
# 		保存网页 Put_option
# 	44 保存关系 Finance	->	Performance_bonds
# 		保存网页 Performance_bonds
# 	45 保存关系 Finance	->	Repurchase_agreement
# 		保存网页 Repurchase_agreement
# 	46 保存关系 Finance	->	Stock
# 		保存网页 Stock
# 	47 保存关系 Finance	->	Security_(finance)
# 		保存网页 Security_(finance)
# 	48 保存关系 Finance	->	Syndicated_loan
# 		保存网页 Syndicated_loan
# 	49 保存关系 Finance	->	Synthetic_CDO
# 		保存网页 Synthetic_CDO
# 	50 保存关系 Finance	->	Corporate_finance
# 		保存网页 Corporate_finance
# 	51 保存关系 Finance	->	Accounting
# 		保存网页 Accounting
# 	52 保存关系 Finance	->	Audit
# 		保存网页 Audit
# 	53 保存关系 Finance	->	Capital_budgeting
# 		保存网页 Capital_budgeting
# 	54 保存关系 Finance	->	Credit_rating_agency
# 		保存网页 Credit_rating_agency
# 	55 保存关系 Finance	->	Financial_risk_management
# 		保存网页 Financial_risk_management
# 	56 保存关系 Finance	->	Financial_statement
# 		保存网页 Financial_statement
# 	57 保存关系 Finance	->	Leveraged_buyout
# 		保存网页 Leveraged_buyout
# 	58 保存关系 Finance	->	Mergers_and_acquisitions
# 		保存网页 Mergers_and_acquisitions
# 	59 保存关系 Finance	->	Structured_finance
# 		保存网页 Structured_finance
# 	60 保存关系 Finance	->	Venture_capital
# 		保存网页 Venture_capital
# 	61 保存关系 Finance	->	Corporate_tax
# 		保存网页 Corporate_tax
# 	62 保存关系 Finance	->	Base_erosion_and_profit_shifting
# 		保存网页 Base_erosion_and_profit_shifting
# 	63 保存关系 Finance	->	Corporate_tax_haven
# 		保存网页 Corporate_tax_haven
# 	64 保存关系 Finance	->	Tax_inversion
# 		保存网页 Tax_inversion
# 	65 保存关系 Finance	->	Tax_haven
# 		保存网页 Tax_haven
# 	66 保存关系 Finance	->	Transfer_pricing
# 		保存网页 Transfer_pricing
# 	67 保存关系 Finance	->	Personal_finance
# 		保存网页 Personal_finance
# 	68 保存关系 Finance	->	Credit_(finance)
# 		保存网页 Credit_(finance)
# 	69 保存关系 Finance	->	Consumer_debt
# 		保存网页 Consumer_debt
# 	70 保存关系 Finance	->	Employment_contract
# 		保存网页 Employment_contract
# 	71 保存关系 Finance	->	Financial_planner
# 		保存网页 Financial_planner
# 	72 保存关系 Finance	->	Retirement
# 		保存网页 Retirement
# 	73 保存关系 Finance	->	Student_loan
# 		保存网页 Student_loan
# 	74 保存关系 Finance	->	Public_finance
# 		保存网页 Public_finance
# 	75 保存关系 Finance	->	Government_spending
# 		保存网页 Government_spending
# 	76 保存关系 Finance	->	Government_final_consumption_expenditure
# 		保存网页 Government_final_consumption_expenditure
# 	77 保存关系 Finance	->	Government_operations
# 		保存网页 Government_operations
# 	78 保存关系 Finance	->	Redistribution_of_income_and_wealth
# 		保存网页 Redistribution_of_income_and_wealth
# 	79 保存关系 Finance	->	Transfer_payment
# 		保存网页 Transfer_payment
# 	80 保存关系 Finance	->	Government_revenue
# 		保存网页 Government_revenue
# 	81 保存关系 Finance	->	Tax
# 		保存网页 Tax
# 	82 保存关系 Finance	->	Deficit_spending
# 		保存网页 Deficit_spending
# 	83 保存关系 Finance	->	Government_budget
# 		保存网页 Government_budget
# 	84 保存关系 Finance	->	Government_budget_balance
# 		保存网页 Government_budget_balance
# 	85 保存关系 Finance	->	Government_debt
# 		保存网页 Government_debt
# 	86 保存关系 Finance	->	Non-tax_revenue
# 		保存网页 Non-tax_revenue
# 	87 保存关系 Finance	->	Warrant_of_payment
# 		保存网页 Warrant_of_payment
# 	88 保存关系 Finance	->	Bank
# 		保存网页 Bank
# 	89 保存关系 Finance	->	Central_bank
# 		保存网页 Central_bank
# 	90 保存关系 Finance	->	Deposit_account
# 	91 保存关系 Finance	->	Fractional-reserve_banking
# 		保存网页 Fractional-reserve_banking
# 当前连接失败...放弃并继续
# 	92 保存关系 Finance	->	Full-reserve_banking
# 		保存网页 Full-reserve_banking
# 	93 保存关系 Finance	->	Loan
# 	94 保存关系 Finance	->	Money_supply
# 		保存网页 Money_supply
# 	95 保存关系 Finance	->	Lists_of_banks
# 		保存网页 Lists_of_banks
# 	96 保存关系 Finance	->	Bank_regulation
# 		保存网页 Bank_regulation
# 	97 保存关系 Finance	->	Banking_license
# 		保存网页 Banking_license
# 	98 保存关系 Finance	->	Basel_Accords
# 		保存网页 Basel_Accords
# 	99 保存关系 Finance	->	Bank_for_International_Settlements
# 		保存网页 Bank_for_International_Settlements
# 	100 保存关系 Finance	->	Financial_Stability_Board
# 		保存网页 Financial_Stability_Board
# 	101 保存关系 Finance	->	Deposit_insurance
# 		保存网页 Deposit_insurance
# 	102 保存关系 Finance	->	Separation_of_investment_and_retail_banking
# 		保存网页 Separation_of_investment_and_retail_banking
# 	103 保存关系 Finance	->	Financial_regulation
# 		保存网页 Financial_regulation
# 	104 保存关系 Finance	->	Financial_law
# 		保存网页 Financial_law
# 	105 保存关系 Finance	->	International_Financial_Reporting_Standards
# 		保存网页 International_Financial_Reporting_Standards
# 	106 保存关系 Finance	->	ISO_31000
# 		保存网页 ISO_31000
# 	107 保存关系 Finance	->	Professional_certification_in_financial_services
# 		保存网页 Professional_certification_in_financial_services
# 	108 保存关系 Finance	->	Fund_governance
# 		保存网页 Fund_governance
# 	109 保存关系 Finance	->	Economic_history
# 		保存网页 Economic_history
# 	110 保存关系 Finance	->	History_of_private_equity_and_venture_capital
# 		保存网页 History_of_private_equity_and_venture_capital
# 	111 保存关系 Finance	->	Recession
# 		保存网页 Recession
# 	112 保存关系 Finance	->	Stock_market_bubble
# 		保存网页 Stock_market_bubble
# 	113 保存关系 Finance	->	Stock_market_crash
# 		保存网页 Stock_market_crash
# 	114 保存关系 Finance	->	Accounting_scandals
# 		保存网页 Accounting_scandals
# 	115 保存关系 Finance	->	Capital_(finance)
# 		保存网页 Capital_(finance)
# 	116 保存关系 Finance	->	Investment
# 		保存网页 Investment
# 	117 保存关系 Finance	->	Corporate_finance
# 	118 保存关系 Finance	->	Personal_finance
# 	119 保存关系 Finance	->	Public_finance
# 	120 保存关系 Finance	->	Financial_market
# 	121 保存关系 Finance	->	Financial_instruments
# 		保存网页 Financial_instruments
# 	122 保存关系 Finance	->	Financial_services
# 		保存网页 Financial_services
# 	123 保存关系 Finance	->	Investment_management
# 		保存网页 Investment_management
# 	124 保存关系 Finance	->	Money_management
# 		保存网页 Money_management
# 	125 保存关系 Finance	->	Asset_management
# 		保存网页 Asset_management
# 	126 保存关系 Finance	->	Securities_trading
# 		保存网页 Securities_trading
# 	127 保存关系 Finance	->	Stock_broking
# 		保存网页 Stock_broking
# 	128 保存关系 Finance	->	Investment_bank
# 		保存网页 Investment_bank
# 	129 保存关系 Finance	->	Financial_engineering
# 		保存网页 Financial_engineering
# 	130 保存关系 Finance	->	Risk_management
# 		保存网页 Risk_management
# 	131 保存关系 Finance	->	Asset
# 		保存网页 Asset
# 	132 保存关系 Finance	->	Liability_(financial_accounting)
# 		保存网页 Liability_(financial_accounting)
# 	133 保存关系 Finance	->	Valuation_(finance)
# 		保存网页 Valuation_(finance)
# 	134 保存关系 Finance	->	Asset_allocation
# 		保存网页 Asset_allocation
# 	135 保存关系 Finance	->	Time_value_of_money
# 		保存网页 Time_value_of_money
# 	136 保存关系 Finance	->	Present_value
# 		保存网页 Present_value
# 	137 保存关系 Finance	->	Required_rate_of_return
# 		保存网页 Required_rate_of_return
# 	138 保存关系 Finance	->	Financial_economics
# 		保存网页 Financial_economics
# 	139 保存关系 Finance	->	Mathematical_finance
# 		保存网页 Mathematical_finance
# 	140 保存关系 Finance	->	Valuation_(finance)
# 	141 保存关系 Finance	->	Management#Training
# 		保存网页 Management#Training
# 	142 保存关系 Finance	->	Financial_economics
# 	143 保存关系 Finance	->	Economics
# 		保存网页 Economics
# 	144 保存关系 Finance	->	Accountancy
# 		保存网页 Accountancy
# 	145 保存关系 Finance	->	Applied_mathematics
# 		保存网页 Applied_mathematics
# 	146 保存关系 Finance	->	Outline_of_finance#Education
# 		保存网页 Outline_of_finance#Education
# 	147 保存关系 Finance	->	List_of_unsolved_problems_in_finance
# 		保存网页 List_of_unsolved_problems_in_finance
# 	148 保存关系 Finance	->	Financial_services
# 	149 保存关系 Finance	->	Financial_market
# 	150 保存关系 Finance	->	Expense
# 		保存网页 Expense
# 	151 保存关系 Finance	->	Equity_(finance)
# 		保存网页 Equity_(finance)
# 	152 保存关系 Finance	->	Lender
# 		保存网页 Lender
# 	153 保存关系 Finance	->	Debtor
# 		保存网页 Debtor
# 	154 保存关系 Finance	->	Financial_intermediary
# 		保存网页 Financial_intermediary
# 	155 保存关系 Finance	->	Bank
# 	156 保存关系 Finance	->	Government_bond
# 		保存网页 Government_bond
# 	157 保存关系 Finance	->	Bond_market
# 	158 保存关系 Finance	->	Personal_finance
# 	159 保存关系 Finance	->	Public_finance
# 	160 保存关系 Finance	->	Corporate_finance
# 	161 保存关系 Finance	->	Business_management
# 		保存网页 Business_management
# 	162 保存关系 Finance	->	Capital_structure
# 		保存网页 Capital_structure
# 	163 保存关系 Finance	->	Equity_financing
# 		保存网页 Equity_financing
# 	164 保存关系 Finance	->	Institutional_investor
# 	165 保存关系 Finance	->	Pension_fund
# 		保存网页 Pension_fund
# 	166 保存关系 Finance	->	Private_investors
# 		保存网页 Private_investors
# 	167 保存关系 Finance	->	Personal_finance
# 	168 保存关系 Finance	->	Durable_good
# 		保存网页 Durable_good
# 	169 保存关系 Finance	->	Real_estate
# 	170 保存关系 Finance	->	Insurance
# 	171 保存关系 Finance	->	Retirement
# 	172 保存关系 Finance	->	Corporate_finance
# 	173 保存关系 Finance	->	Capital_structure
# 	174 保存关系 Finance	->	Equity_(finance)
# 	175 保存关系 Finance	->	Debt
# 		保存网页 Debt
# 	176 保存关系 Finance	->	Financial_management
# 		保存网页 Financial_management
# 	177 保存关系 Finance	->	Working_capital_management
# 		保存网页 Working_capital_management
# 	178 保存关系 Finance	->	Cash_management
# 		保存网页 Cash_management
# 	179 保存关系 Finance	->	Inventory
# 		保存网页 Inventory
# 	180 保存关系 Finance	->	Debtor
# 	181 保存关系 Finance	->	Stock
# 	182 保存关系 Finance	->	Capital_budgeting
# 	183 保存关系 Finance	->	Business_valuation
# 		保存网页 Business_valuation
# 	184 保存关系 Finance	->	Real_options_valuation
# 		保存网页 Real_options_valuation
# 	185 保存关系 Finance	->	Financial_modeling#Accounting
# 		保存网页 Financial_modeling#Accounting
# 	186 保存关系 Finance	->	Equity_(finance)
# 	187 保存关系 Finance	->	Initial_public_offering
# 		保存网页 Initial_public_offering
# 	188 保存关系 Finance	->	Creditor
# 		保存网页 Creditor
# 	189 保存关系 Finance	->	Bond_(finance)
# 	190 保存关系 Finance	->	Cash_flow
# 		保存网页 Cash_flow
# 	191 保存关系 Finance	->	Working_capital
# 		保存网页 Working_capital
# 	192 保存关系 Finance	->	Capital_structure
# 	193 保存关系 Finance	->	Dividend_policy
# 		保存网页 Dividend_policy
# 	194 保存关系 Finance	->	Financial_risk_management
# 	195 保存关系 Finance	->	Economic_value
# 		保存网页 Economic_value
# 	196 保存关系 Finance	->	Business
# 		保存网页 Business
# 	197 保存关系 Finance	->	Financial_instrument
# 	198 保存关系 Finance	->	Financial_risk
# 		保存网页 Financial_risk
# 	199 保存关系 Finance	->	Credit_risk
# 		保存网页 Credit_risk
# 	200 保存关系 Finance	->	Market_risk
# 		保存网页 Market_risk
# 	201 保存关系 Finance	->	Foreign_exchange_risk
# 		保存网页 Foreign_exchange_risk
# 	202 保存关系 Finance	->	Volatility_(finance)
# 		保存网页 Volatility_(finance)
# 	203 保存关系 Finance	->	Liquidity_risk
# 		保存网页 Liquidity_risk
# 	204 保存关系 Finance	->	Inflation
# 		保存网页 Inflation
# 	205 保存关系 Finance	->	Hedge_(finance)
# 		保存网页 Hedge_(finance)
# 	206 保存关系 Finance	->	Financial_engineering
# 	207 保存关系 Finance	->	Risk_management
# 	208 保存关系 Finance	->	Risk_measure#Examples
# 		保存网页 Risk_measure#Examples
# 	209 保存关系 Finance	->	Basel_Accords
# 	210 保存关系 Finance	->	Accounting_profession
# 		保存网页 Accounting_profession
# 	211 保存关系 Finance	->	Financial_accounting
# 		保存网页 Financial_accounting
# 	212 保存关系 Finance	->	Shareholder
# 		保存网页 Shareholder
# 	213 保存关系 Finance	->	Public_finance
# 	214 保存关系 Finance	->	Municipal_bond
# 		保存网页 Municipal_bond
# 	215 保存关系 Finance	->	Federal_Reserve_System
# 		保存网页 Federal_Reserve_System
# 	216 保存关系 Finance	->	United_States
# 		保存网页 United_States
# 	217 保存关系 Finance	->	Bank_of_England
# 		保存网页 Bank_of_England
# 	218 保存关系 Finance	->	United_Kingdom
# 		保存网页 United_Kingdom
# 	219 保存关系 Finance	->	Lender_of_last_resort
# 		保存网页 Lender_of_last_resort
# 	220 保存关系 Finance	->	Financial_economics
# 	221 保存关系 Finance	->	Economics
# 	222 保存关系 Finance	->	Variable_(mathematics)
# 		保存网页 Variable_(mathematics)
# 	223 保存关系 Finance	->	Price
# 		保存网页 Price
# 	224 保存关系 Finance	->	Interest_rate
# 		保存网页 Interest_rate
# 	225 保存关系 Finance	->	Goods_and_services
# 		保存网页 Goods_and_services
# 	226 保存关系 Finance	->	Real_vs._nominal_in_economics
# 		保存网页 Real_vs._nominal_in_economics
# 	227 保存关系 Finance	->	Financial_market
# 	228 保存关系 Finance	->	Economic_model
# 		保存网页 Economic_model
# 	229 保存关系 Finance	->	Financial_model
# 		保存网页 Financial_model
# 	230 保存关系 Finance	->	Homo_economicus
# 		保存网页 Homo_economicus
# 	231 保存关系 Finance	->	Investment
# 	232 保存关系 Finance	->	Rational_pricing
# 		保存网页 Rational_pricing
# 	233 保存关系 Finance	->	Efficient-market_hypothesis
# 		保存网页 Efficient-market_hypothesis
# 	234 保存关系 Finance	->	Modern_portfolio_theory
# 		保存网页 Modern_portfolio_theory
# 	235 保存关系 Finance	->	Capital_asset_pricing_model
# 		保存网页 Capital_asset_pricing_model
# 	236 保存关系 Finance	->	Black%E2%80%93Scholes_model
# 		保存网页 Black%E2%80%93Scholes_model
# 	237 保存关系 Finance	->	Valuation_of_options
# 		保存网页 Valuation_of_options
# 	238 保存关系 Finance	->	Certainty
# 		保存网页 Certainty
# 	239 保存关系 Finance	->	Fisher_separation_theorem
# 		保存网页 Fisher_separation_theorem
# 	240 保存关系 Finance	->	The_Theory_of_Investment_Value
# 		保存网页 The_Theory_of_Investment_Value
# 	241 保存关系 Finance	->	Modigliani%E2%80%93Miller_theorem
# 		保存网页 Modigliani%E2%80%93Miller_theorem
# 	242 保存关系 Finance	->	Financial_econometrics
# 		保存网页 Financial_econometrics
# 	243 保存关系 Finance	->	Financial_mathematics
# 		保存网页 Financial_mathematics
# 	244 保存关系 Finance	->	Applied_mathematics
# 	245 保存关系 Finance	->	Financial_market
# 	246 保存关系 Finance	->	Financial_economics
# 	247 保存关系 Finance	->	Mathematical_finance
# 	248 保存关系 Finance	->	Mathematical_model
# 		保存网页 Mathematical_model
# 	249 保存关系 Finance	->	Numerical_analysis
# 		保存网页 Numerical_analysis
# 	250 保存关系 Finance	->	Computational_finance
# 		保存网页 Computational_finance
# 	251 保存关系 Finance	->	Financial_engineering
# 	252 保存关系 Finance	->	Quantitative_analyst
# 		保存网页 Quantitative_analyst
# 	253 保存关系 Finance	->	Derivative_(finance)
# 	254 保存关系 Finance	->	Actuarial_science
# 		保存网页 Actuarial_science
# 	255 保存关系 Finance	->	Portfolio_(finance)
# 		保存网页 Portfolio_(finance)
# 	256 保存关系 Finance	->	Outline_of_finance#Mathematical_tools
# 		保存网页 Outline_of_finance#Mathematical_tools
# 	257 保存关系 Finance	->	Outline_of_finance#Derivatives_pricing
# 		保存网页 Outline_of_finance#Derivatives_pricing
# 	258 保存关系 Finance	->	Experimental_finance
# 		保存网页 Experimental_finance
# 	259 保存关系 Finance	->	Experimental_finance
# 	260 保存关系 Finance	->	Behavioral_economics
# 		保存网页 Behavioral_economics
# 	261 保存关系 Finance	->	Behavioral_finance
# 		保存网页 Behavioral_finance
# 	262 保存关系 Finance	->	Psychology
# 		保存网页 Psychology
# 	263 保存关系 Finance	->	Quantitative_behavioral_finance
# 		保存网页 Quantitative_behavioral_finance
# 	264 保存关系 Finance	->	Gunduz_Caginalp
# 		保存网页 Gunduz_Caginalp
# 	265 保存关系 Finance	->	Journal_of_Behavioral_Finance
# 		保存网页 Journal_of_Behavioral_Finance
# 	266 保存关系 Finance	->	Vernon_L._Smith
# 		保存网页 Vernon_L._Smith
# 	267 保存关系 Finance	->	Financial_crisis_of_2007%E2%80%932010
# 		保存网页 Financial_crisis_of_2007%E2%80%932010
# 	268 保存关系 Finance	->	Outline_of_finance
# 		保存网页 Outline_of_finance
# 	269 保存关系 Finance	->	ISBN_(identifier)
# 		保存网页 ISBN_(identifier)
# 	270 保存关系 Finance	->	Doi_(identifier)
# 		保存网页 Doi_(identifier)
# 	271 保存关系 Finance	->	ISBN_(identifier)
# 	272 保存关系 Finance	->	ISBN_(identifier)
# 	273 保存关系 Finance	->	ISBN_(identifier)
# 	274 保存关系 Finance	->	Wayback_Machine
# 		保存网页 Wayback_Machine
# 	275 保存关系 Finance	->	ISBN_(identifier)
# 	276 保存关系 Finance	->	Wikisource
# 		保存网页 Wikisource
# 	277 保存关系 Finance	->	Collier%27s_Encyclopedia
# 		保存网页 Collier%27s_Encyclopedia
# 	278 保存关系 Finance	->	New_York_University_Stern_School_of_Business
# 		保存网页 New_York_University_Stern_School_of_Business
# 	279 保存关系 Finance	->	Financial_technology
# 		保存网页 Financial_technology
# 	280 保存关系 Finance	->	Computational_finance
# 	281 保存关系 Finance	->	Experimental_finance
# 	282 保存关系 Finance	->	Financial_economics
# 	283 保存关系 Finance	->	Financial_institution
# 		保存网页 Financial_institution
# 	284 保存关系 Finance	->	Financial_management
# 	285 保存关系 Finance	->	Financial_market
# 	286 保存关系 Finance	->	Investment_management
# 	287 保存关系 Finance	->	Mathematical_finance
# 	288 保存关系 Finance	->	Personal_finance
# 	289 保存关系 Finance	->	Public_finance
# 	290 保存关系 Finance	->	Quantitative_behavioral_finance
# 	291 保存关系 Finance	->	Quantum_finance
# 		保存网页 Quantum_finance
# 	292 保存关系 Finance	->	Statistical_finance
# 		保存网页 Statistical_finance
# 	293 保存关系 Finance	->	LCCN_(identifier)
# 		保存网页 LCCN_(identifier)
# 	294 保存关系 Finance	->	National_Archives_and_Records_Administration
# 		保存网页 National_Archives_and_Records_Administration
# 	295 保存关系 Finance	->	National_Diet_Library
# 		保存网页 National_Diet_Library
# 	所有网页数： 234
